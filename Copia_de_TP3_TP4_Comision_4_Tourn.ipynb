# %% [markdown]
# <a href="https://colab.research.google.com/github/tomas-tourn/phyton-ciencia-de-datos/blob/main/Copia_de_TP3_TP4_Comision_4_Tourn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TRABAJO PRACTICO N 3

# %% [markdown]
# ***TEMAS A DESARROLLAR:***
#
# Nociones de Probabilidad, simulación de procesos aleatorios, cálculo de parámetros estadisticos: Media o Valor Esperado(PROMEDIO), Mediana, Desvio Estandar. DISTRIBUCIONES DE PROABABILIDAD más frecuentes, por ejemplo la Normal.

# %% [markdown]
# ## Funciones estadísticas para análisis exploratorio de datos
# A continuación se presentan ejemplos de funciones estadísticas para el análisis exploratorio de datos utilizando NumPy:

# %% [markdown]
# #### Crear array aleatorio
# En esta celda, se utiliza la función np.random.rand() de NumPy para crear un array de números aleatorios con una forma específica. Luego, se imprime el array.

# %%
import numpy as np
random_array = np.random.randint(0,10, (4,3))
print("Array aleatorio:", random_array)
# Out:
# Array aleatorio: [[0 5 8]
#  [5 5 9]
#  [8 7 5]
#  [9 0 0]]

# %% [markdown]
# #### Media
# En esta celda, se crea un array 'array' y se utiliza la función np.mean() de NumPy para calcular la media del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
media = np.mean(array)
print("Media:", media)
# Out:
# Media: 3.0

# %% [markdown]
# #### Desviación estándar
# En esta celda, se crea un array 'array' y se utiliza la función np.std() de NumPy para calcular la desviación estándar del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
desviacion_estandar = np.std(array)
print("Desviación estándar:", desviacion_estandar)
# Out:
# Desviación estándar: 1.4142135623730951

# %% [markdown]
# #### Varianza
# La función np.var() se utiliza para calcular la varianza de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
varianza = np.var(array)
print("Varianza:", varianza)
# Out:
# Varianza: 2.0

# %% [markdown]
# #### Valor mínimo
# En esta celda, se crea un array 'array' y se utiliza la función np.min() de NumPy para encontrar el valor mínimo del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
matriz=np.random.randint(-3,3,(5,5))
#minimo = np.min(array)
minimo = np.min(matriz, axis=0)
print("Valor mínimo:", minimo)
print( matriz)
# Out:
# Valor mínimo: [-2 -2 -2 -3 -3]
# [[-2  2  0 -3  0]
#  [ 2  1 -1  0 -3]
#  [ 1  2 -2 -1 -1]
#  [-1 -2 -2 -1 -3]
#  [-1  0  0  0  2]]

# %% [markdown]
# #### Valor máximo
# En esta celda, se crea un array 'array' y se utiliza la función np.max() de NumPy para encontrar el valor máximo del array. Luego, se imprime el resultado.

# %%
maximo = np.max(array)
print("Valor máximo:", maximo)
# Out:
# Valor máximo: 5

# %% [markdown]
# #### Gráfico de dispersión
# En esta celda, se crea un array 'x' con valores aleatorios y un array 'y' con valores aleatorios. Luego, se utiliza la biblioteca Matplotlib para trazar un gráfico de dispersión con 'x' en el eje x y 'y' en el eje y. También se agrega etiquetas y un título al gráfico.

# %%
x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de dispersión')
plt.show()

# %% [markdown]
# En esta celda, se crea un array 'data' con valores aleatorios siguiendo una distribución normal. Luego, se utiliza la biblioteca Matplotlib para trazar un histograma de 'data'. También se agrega etiquetas y un título al gráfico.

# %%
data = np.random.normal(0, 1, 1000)

plt.hist(data, bins=30)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma')
plt.show()

# %% [markdown]
# #### Mediana
# La función np.median() se utiliza para calcular la mediana de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
mediana = np.median(array)
print("Mediana:", mediana)
# Out:
# Mediana: 3.0

# %% [markdown]
# #### Percentiles
# La función np.percentile() se utiliza para calcular los percentiles de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
percentil_50 = np.percentile(array, 50)
print("Percentil 50:", percentil_50)
# Out:
# Percentil 50: 3.0

# %% [markdown]
# # EJEMPLOS Y APLICACIÓNES

# %% [markdown]
# ***APLICACIÓN DE PROBABILIDAD***
#
# Se Realiza el lanzamiento de un dado EQUILIBRADO JUSTO, de manera reiterada con las mismas condiciones, y se anotan sus resultados= CARA O CRUZ.
#
# Se le pide al usuario que defina la cantidad N de lanzamientos y se calcula su frecuencia relativa= 'PROBABILIDAD' de obtener cara o cruz. Se obtiene los siguientes resultados:

# %%
import numpy as np
n=int(input('ingrese la cantidad de simulación o lanzamientos'))

#========= FORMA 1 DE SIMULAR LANZAMIENTO DE UN DADO============
dado=[]
cara=0
cruz=0
for i in range(n):
  dado.append(np.random.rand(1))
  dado1=np.array(dado)
  if dado1[i]<0.5:
    #print('salio cara')
    #print(dado[i])
    cara +=1
  else:
    #print('salio cruz')
    #print(dado[i])
    cruz +=1
# Out:
# ingrese la cantidad de simulación o lanzamientos50

# %%
#  mostrar la probailidad frecuencista de el lanzamiento de un dado
prom_cara=cara/n
prom_cruz=cruz/n
print('la probabilidad aproximada en '+str(n)+' lanzamientos de sacar CARA es:', prom_cara)
print('la probabilidad aproximada en '+str(n)+' lanzamientos de sacar CRUZ es:', prom_cruz)
# Out:
# la probabilidad aproximada en 100 lanzamientos de sacar CARA es: 0.47
# la probabilidad aproximada en 100 lanzamientos de sacar CRUZ es: 0.53

# %%
#========== FORMA COMPACTA DE SIMULAR USANDO NUMPY===========
m=int(input('ingrese la cantidad de simulación o lanzamientos'))
lanzamientos = np.random.randint(0, 2, m)

# Calcular las probabilidades

probabilidad_cara = np.sum(lanzamientos ==0 ) / len(lanzamientos)
probabilidad_sello = np.sum(lanzamientos== 1) / len(lanzamientos)

print(f"Probabilidad de cara: {probabilidad_cara:.2f}")
print(f"Probabilidad de sello: {probabilidad_sello:.2f}")
# Out:
# ingrese la cantidad de simulación o lanzamientos100
# Probabilidad de cara: 0.53
# Probabilidad de sello: 0.47

# %%
import matplotlib.pyplot as plt
x=np.array(range(2))
y=np.array([probabilidad_cara, probabilidad_sello])

plt.bar(x,y)
plt.xlabel('Opción')
plt.ylabel('Frecuencia relativa')
plt.title('Histograma del lanzamiento de una moneda equilibrada')
plt.show()

# %% [markdown]
# # EJERCICIOS

# %% [markdown]
# ##***EJERCICIO 1***
#
# Simular el lanzamiento de un dado eqilibrado de 6 caras.
#
#
# *   Mostrar la probabilida aproximada de obtener el número 2, 3 y 5
# *   Graficar el histograma de las probabilidades

# %%
import numpy as np

m=int(input('ingrese la cantidad de simulación o lanzamientos'))
lanzamientos = np.random.randint(1, 6, m)

# Calcular las probabilidades

probabilidad_2 = np.sum(lanzamientos== 2 ) / len(lanzamientos)
probabilidad_3 = np.sum(lanzamientos== 3) / len(lanzamientos)
probabilidad_5 = np.sum(lanzamientos== 5) / len(lanzamientos)

print(f"Probabilidad de obtener 2: {probabilidad_2:.2f}")
print(f"Probabilidad de obtener 3: {probabilidad_3:.2f}")
print(f"Probabilidad de obtener 5: {probabilidad_5:.2f}")
# Out:
# ingrese la cantidad de simulación o lanzamientos350
# Probabilidad de obtener 2: 0.16
# Probabilidad de obtener 3: 0.21
# Probabilidad de obtener 5: 0.18

# %%
import matplotlib.pyplot as plt
x=np.array(range(3))
y=np.array([probabilidad_2, probabilidad_3,probabilidad_5])

plt.bar(x,y)
plt.xlabel('Cara')
plt.ylabel('Frecuencia relativa')
plt.title('Histograma de las probabilidades 2, 3 y 5 de un dado equilibrado')
plt.show()

# %% [markdown]
# ## EJERCICIO 4
#
# Dada la base de datos de ventas diarias durante una semana, de un negocio con 4 productos.- VER EJERCICIO PARTE 2 PRACTICO N 2- Realizar el siguiente análisis de datos para poder obtener información y planificar una estrategia de ventas.
#
#
# 1.   Calcular la media en la ventas por cada producto y la mediana. Plotear estos nuevos datos en un gráfico de barra.
# 2.    Calcular la media en la ventas por DÍA y la mediana. Plotear estos nuevos datos en un gráfico de TRAZO DE LINEAS.
# 3.   Realizar una conclusión en función las graficas y sugerir al menos 5 estrategias de venta o inversión de manera de potenciar este negocio.
# 4.   Calcular el desvio estandar de los datos por cada producto y concluir para cada producto como es su rango de variabilidad en las ventas de los mismos.Plotear los datos de ventas de la semana de los productos con mayor y menor desvio estandar y evidenciar la variabilidad indicada en el parametro *'DESVIO ESTANDAR'*

# %%
a=[20, 15, 25, 30, 18, 22, 24]  #Producto A
b=[12, 20, 14, 8, 15, 18, 16]   #Producto B
c=[35, 28, 32, 30, 26, 24, 30]  #Producto C
d=[40, 38, 45, 42, 39, 41, 37]  #Producto D

lista_py_ventas=[a,
                 b,
                 c,
                 d]
vector_np_ventas=np.array(lista_py_ventas)
print(vector_np_ventas)
# Out:
# [[20 15 25 30 18 22 24]
#  [12 20 14  8 15 18 16]
#  [35 28 32 30 26 24 30]
#  [40 38 45 42 39 41 37]]

# %% [markdown]
# # **1) media y mediana de ventas por producto**

# %%
media_por_producto=np.mean(vector_np_ventas, axis=1)
mediana_por_producto=np.median(vector_np_ventas, axis=1)

media_producto_A= media_por_producto[0]
print(f"media producto A: {media_producto_A}")
mediana_producto_A =  mediana_por_producto[0]
print("Mediana producto A:", mediana_producto_A)

media_producto_B= media_por_producto[1]
print(f"media producto B: {media_producto_B}")
mediana_producto_B =  mediana_por_producto[1]
print("Mediana producto B:", mediana_producto_B)

media_producto_C= media_por_producto[2]
print(f"media producto C: {media_producto_C}")
mediana_producto_C =  mediana_por_producto[2]
print("Mediana producto C:", mediana_producto_C)


media_producto_D= media_por_producto[3]
print(f"media producto D: {media_producto_D}")
mediana_producto_D =  mediana_por_producto[3]
print("Mediana producto D:", mediana_producto_D)
# Out:
# media producto A: 22.0
# Mediana producto A: 22.0
# media producto B: 14.714285714285714
# Mediana producto B: 15.0
# media producto C: 29.285714285714285
# Mediana producto C: 30.0
# media producto D: 40.285714285714285
# Mediana producto D: 40.0

# %%
import matplotlib.pyplot as plt
productos = ['Producto A', 'Producto B', 'Producto C', 'Producto D']

x = np.arange(len(productos))

width = 0.35

# gráfico de barras
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, media_por_producto, width, label='Media')
rects2 = ax.bar(x + width/2, mediana_por_producto, width, label='Mediana')

ax.set_xlabel('Productos')
ax.set_ylabel('Valor')
ax.set_title('Media y Mediana de Ventas por Producto')
ax.set_xticks(x)
ax.set_xticklabels(productos)
ax.legend()
plt.show()

# %% [markdown]
# # **2) Media y Mediana de ventas por día**

# %%
media_por_dia =np.mean(vector_np_ventas, axis=0)
mediana_por_dia=np.median(vector_np_ventas, axis=0)

media_dia_lunes= media_por_dia[0]
print(f"media lunes: {media_dia_lunes}")
mediana_dia_lunes =  mediana_por_dia[0]
print("Mediana lunes:", mediana_dia_lunes)

media_dia_martes= media_por_dia[1]
print(f"media martes: {media_dia_martes}")
mediana_dia_martes =  mediana_por_dia[1]
print("Mediana martes:", mediana_dia_martes)

media_dia_miercoles= media_por_dia[2]
print(f"media miercoles: {media_dia_miercoles}")
mediana_dia_miercoles =  mediana_por_dia[2]
print("Mediana miercoles:", mediana_dia_miercoles)


media_dia_jueves= media_por_dia[3]
print(f"media jueves: {media_dia_jueves}")
mediana_dia_jueves =  mediana_por_dia[3]
print("Mediana jueves:", mediana_dia_jueves)

media_dia_viernes= media_por_dia[4]
print(f"media viernes: {media_dia_viernes}")
mediana_dia_viernes =  mediana_por_dia[4]
print("Mediana viernes:", mediana_dia_viernes)

media_dia_sabado= media_por_dia[5]
print(f"media sabado: {media_dia_sabado}")
mediana_dia_sabado =  mediana_por_dia[5]
print("Mediana sabado:", mediana_dia_sabado)

media_dia_domingo= media_por_dia[6]
print(f"media domingo: {media_dia_domingo}")
mediana_dia_domingo =  mediana_por_dia[6]
print("Mediana domingo:", mediana_dia_domingo)
# Out:
# media lunes: 26.75
# Mediana lunes: 27.5
# media martes: 25.25
# Mediana martes: 24.0
# media miercoles: 29.0
# Mediana miercoles: 28.5
# media jueves: 27.5
# Mediana jueves: 30.0
# media viernes: 24.5
# Mediana viernes: 22.0
# media sabado: 26.25
# Mediana sabado: 23.0
# media domingo: 26.75
# Mediana domingo: 27.0

# %%
dias_semana = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo']

# gráfico de trazo de líneas
plt.plot(dias_semana, media_por_dia, label='Media')
plt.plot(dias_semana, mediana_por_dia, label='Mediana')

plt.xlabel('Días de la Semana')
plt.ylabel('Valor')
plt.title('Media y Mediana de Ventas por Día')
plt.legend()

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **3) Conclusión:**
#
# A partir de un análisis de los graficos puedo notar tendencias.
#
# ***Ventas por Producto:*** Los productos A y B  presentan en promedio ventas mas bajas que los productos C y D . Se podría entonces pensar en mejorar las ventas de los productos A y B.
#
# ***Ventas por Día:*** Las ventas tienden a ser más altas los días miércoles y jueves, y disminuyen hacia el fin de semana, resaltando como valores muy bajos los martes y los viernes. A partir de esto se podría planificar estrategias promocionales.
#
# ## Estrategias de Venta e Inversión:
#
# ***Promoción de Productos A y B:*** Desarrollar campañas de marketing específicas para aumentar la demanda de los productos A y B. Como pueden ser descuentos, paquetes especiales o incentivos.
#
# ***Optimización del stock:*** Con estos datos de ventas por día podrían ajustarse el inventario en función de la demanda. Esto ayudará a evitar excesos o faltantes de productos en días específicos.
#
# ***Eventos:*** Organizar eventos o promociones especiales en los días de menos venta, como los martes, viernes y sábados, para atraer a más clientes y aumentar la facturación durante esos días.
#
# ***Capacitaciónes al personal:*** Invertir en capacitación del personal para brindar un excelente servicio al cliente puede generar una experiencia positiva para los clientes y generar un boca en boca positivo.
#
# ***Diversificación de Productos:*** Considerar la introducción de nuevos productos o variantes en línea con las preferencias de los clientes. Esto podría ampliar la base de clientes y aumentar las ventas generales.
#
# ***Análisis de Competencia: ***Analizar en profundidad a la competencia podría servir para identificar oportunidades para diferenciarse y capturar un porcentaje más grande del mercado .
#
# En conclusión, la implementación de estas estrategias, podría traducirse en un crecimiento sostenible a largo plazo.

# %% [markdown]
# ## EJERCICIO 5
#
# Solicitar al usuario que ingrese la cantidad N de datos a cargar. Luego generar de manera aleatoria los siguientes datos:
#
# * SEXO= 'MASCULINO', 'FEMENINO','NO ESPECIFICA'
# * EDAD= entre 28 y 60 años
# * ALTURA= entre un rango de 165.0 mts hasta 210 mts
# * PESO= entre un rango de 50  y 110 kg
# * HORAS DE DESCANSO diario= un número decimal
# * HORAS DE TRABAJO/ ESTUDIO diario= un número decimal
# * HORAS DE EJERCICIOS diario= un número decimal
#
# REalizar las siguientes indicaciones y extraer concluisiones sobre la información y la pooblación muestreada.
#
# 1.   Generar un array de dimensión 2 (matriz), con todos los datos ordenados, permitiendo visualizarlos como tabla.
# 2.   Suponiendo que la distribución de probabilidad de los datos muestrados de las N personas, se distribuyen en forma NORMAL. Encontrar la media en los datos de altura, peso, y horas de descanso, trabajo y ejercicios.
# 3.  Graficar la muestra o distribución de los datos  de pesos , y alturas en graficas separadas. Indicar el grado de variabilidad de sus datos
# 4.  Plotear de manera conjunta y encontrar si presentan correlación los datos de peso vs altura,
# 5. Plotear de manera conjunta los datos de horas de descanso, estudio y ejercicio

# %% [markdown]
# **Ayuda Como generar los datos**

# %%
import numpy as np
import matplotlib.pyplot as plt

def generar_datos(N):
    sexo = np.random.choice(['MASCULINO', 'FEMENINO', 'NO ESPECIFICA'], N ,[0.4, 0.5, 0.1])  # Por ejemplo, 40% masculino, 50% femenino, 10% no especificado)
    # Generar edades con distribución normal
    edad =np.random.normal(44, 6, N)
    edad=np.clip(np.around(edad),28,60)
    # Generar alturas, pesos y otras características
    altura = np.random.normal(180, 10, N)
    altura = np.clip(np.around(altura, decimals=1), 165.0, 210.0)

    peso = np.random.normal(80, 15, N)
    peso = np.clip(np.around(peso, decimals=1), 50.0, 110.0)

    horas_trabajo_estudio = np.random.normal(10, 2, N)
    horas_trabajo_estudio = np.clip(np.around(horas_trabajo_estudio, decimals=1), 4.0, 12.0)

    horas_ejercicio = np.random.normal(1, 0.5, N)
    horas_ejercicio = np.clip(np.around(horas_ejercicio, decimals=1), 0, 2)

    horas_descanso = 24 - horas_trabajo_estudio - horas_ejercicio
    datos = np.column_stack((sexo, edad, altura, peso, horas_descanso, horas_trabajo_estudio, horas_ejercicio))
    return datos


# Solicitar al usuario la cantidad N de datos a cargar
N=int(input('ingrese la cantidad de datos N: '))

# Generar datos aleatorios para N personas con distribución normal y límites específicos
datos = generar_datos(N)
# Out:
# ingrese la cantidad de datos N: 980

# %% [markdown]
# ## **1) Array**

# %%
import pandas as pd
matriz_datos = np.array(datos)

# DataFrame de pandas para presentar los datos en forma de tabla
columnas = ['Sexo', 'Edad', 'Altura', 'Peso', 'Horas Descanso', 'Horas Trabajo/Estudio', 'Horas Ejercicio']
df = pd.DataFrame(matriz_datos, columns=columnas)

df.head(16)
# Out:
#              Sexo  Edad Altura  Peso      Horas Descanso  \
# 0       MASCULINO  52.0  165.0  82.2  14.399999999999999
# 1       MASCULINO  35.0  176.1  62.8                10.7
# 2        FEMENINO  32.0  196.0  72.1                14.1
# 3   NO ESPECIFICA  36.0  179.9  83.6  13.100000000000001
# 4   NO ESPECIFICA  49.0  172.1  85.4                12.8
# 5        FEMENINO  38.0  165.0  76.0                13.3
# 6       MASCULINO  46.0  187.7  91.2                14.2
# 7        FEMENINO  43.0  179.3  71.3                14.7
# 8        FEMENINO  46.0  174.4  88.0                11.6
# 9        FEMENINO  42.0  180.8  50.6                11.9
# 10      MASCULINO  39.0  168.1  79.3                10.7
# 11       FEMENINO  42.0  192.6  73.8                13.9
# 12       FEMENINO  40.0  204.3  76.7                10.4
# 13       FEMENINO  42.0  188.9  74.0                13.4
# 14      MASCULINO  57.0  173.8  72.3                14.9
# ...

# %% [markdown]
# ## **2) Media de los distintos datos**

# %%
# Se obtienen las columnas específicas
altura = matriz_datos[:, 2].astype(float)
peso = matriz_datos[:, 3].astype(float)
horas_descanso = matriz_datos[:, 4].astype(float)
horas_trabajo_estudio = matriz_datos[:, 5].astype(float)
horas_ejercicio = matriz_datos[:, 6].astype(float)

# Medias de las características
media_altura = np.mean(altura)
media_peso = np.mean(peso)
media_horas_descanso = np.mean(horas_descanso)
media_horas_trabajo_estudio = np.mean(horas_trabajo_estudio)
media_horas_ejercicio = np.mean(horas_ejercicio)

print(f"Media Altura: {media_altura:.2f}")
print(f"Media Peso: {media_peso:.2f}")
print(f"Media Horas Descanso: {media_horas_descanso:.2f}")
print(f"Media Horas Trabajo/Estudio: {media_horas_trabajo_estudio:.2f}")
print(f"Media Horas Ejercicio: {media_horas_ejercicio:.2f}")
# Out:
# Media Altura: 180.18
# Media Peso: 79.15
# Media Horas Descanso: 13.22
# Media Horas Trabajo/Estudio: 9.78
# Media Horas Ejercicio: 1.00

# %% [markdown]
# ## **3) Graficas y grado de variabilidad de sus datos**

# %%
# Columnas específicas de peso y altura
peso = matriz_datos[:, 3].astype(float)    # Convertir a tipo float
altura = matriz_datos[:, 2].astype(float)  # Convertir a tipo float

# Media y desviación estándar
media_peso = np.mean(peso)
desvio_peso = np.std(peso)

media_altura = np.mean(altura)
desvio_altura = np.std(altura)

# Crear histograma de pesos
plt.figure(figsize=(10, 5))
plt.hist(peso, bins=20, color='blue', alpha=0.7)
plt.axvline(x=media_peso, color='red', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(x=media_peso + desvio_peso, color='green', linestyle='dashed', linewidth=2, label='Media + 1 Desvío Estándar')
plt.axvline(x=media_peso - desvio_peso, color='green', linestyle='dashed', linewidth=2, label='Media - 1 Desvío Estándar')
plt.xlabel('Peso')
plt.ylabel('Frecuencia')
plt.title('Distribución de Pesos')
plt.legend()
plt.show()

# Crear histograma de alturas
plt.figure(figsize=(10, 5))
plt.hist(altura, bins=20, color='purple', alpha=0.7)
plt.axvline(x=media_altura, color='red', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(x=media_altura + desvio_altura, color='green', linestyle='dashed', linewidth=2, label='Media + 1 Desvío Estándar')
plt.axvline(x=media_altura - desvio_altura, color='green', linestyle='dashed', linewidth=2, label='Media - 1 Desvío Estándar')
plt.xlabel('Altura')
plt.ylabel('Frecuencia')
plt.title('Distribución de Alturas')
plt.legend()
plt.show()

# %% [markdown]
# ## **4) Correlación entre peso y altura**

# %%
# Se crea un scatter plot conjunto
plt.figure(figsize=(8, 6))
plt.scatter(peso, altura, alpha=0.5, color="green")
plt.xlabel('Peso')
plt.ylabel('Altura')
plt.title('Diagrama de Dispersión Peso vs Altura')
plt.grid()

# Calcular el coeficiente de correlación
coef_corr = np.corrcoef(peso, altura)[0, 1]
print(f"Coeficiente de Correlación: {coef_corr:.2f}")

# Mostrar el gráfico
plt.show()
# Out:
# Coeficiente de Correlación: 0.01

# %% [markdown]
# ## **5) Gráfico de dispersion en conjunto**

# %%
horas_descanso = matriz_datos[:, 4].astype(float)  # Convertir a tipo float
horas_trabajo_estudio = matriz_datos[:, 5].astype(float)  # Convertir a tipo float
horas_ejercicio = matriz_datos[:, 6].astype(float)  # Convertir a tipo float

# Crear un scatter plot conjunto
plt.figure(figsize=(10, 6))
plt.scatter(horas_descanso, horas_trabajo_estudio, c='blue', label='Horas de Descanso vs Trabajo/Estudio', alpha=0.5)
plt.scatter(horas_descanso, horas_ejercicio, c='green', label='Horas de Descanso vs Ejercicio', alpha=0.5)
plt.scatter(horas_trabajo_estudio, horas_ejercicio, c='red', label='Horas de Trabajo/Estudio vs Ejercicio', alpha=0.5)
plt.xlabel('Horas de Descanso')
plt.ylabel('Horas')
plt.title('Diagrama de Dispersión Horas de Descanso, Trabajo/Estudio y Ejercicio')
plt.legend()
plt.grid()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # **TRABAJO PRACTICO N 4**

# %% [markdown]
# **Trabajo Practico Nº 4**
# Analisis sobre data set
#
# 1= Buscar los siguiente data set en la web
# * Titanic
# * Iris
# * Wine
# * Indian Diabetes
#
# 2- Explicar un data set , sus diferente Variables\
# 3- Deside justificando tu respuesta que tipo de categoria de variable son\
# 4- Detectar y arreglar los siguientes coceptos
# * Valores Ausente
# * Valores Atipicos
#
# 5- Sobre el dataset elegido , ¿se puede eliminar alguna fila o columna?\
#
# 6- Realizar analisis univariados
# * Grafico de frecuencia
# * Grafico de torta
# * Histograma
# * etc
#
# 7- En base a los graficos del punto 6 realizar distintas concluciones\
#
# 8- Realizar analisis de matriz corelacion y explicar que variable estan correlacionadas\
#
# PD Pueden Buscar data set de kaggle

# %% [markdown]
# ## De los 4 data set buscados el mas relacionado a mis estudios de biotecnología fue el de Iris por lo tanto lo elegí para analizar.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Archivo CSV de Iris en GitHub
url = 'https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv'
# Se carga el dataset de Iris en un DataFrame
df = pd.read_csv(url)

df.head(11)
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa

# %% [markdown]
# **2) Explicación del dataset**:
# El dataset toma 150 objetos de estudio, en este caso flores de Iris, las cuales analiza a partir de 5 variables, o caracteristicas,  que describen morfológicamente a la flor.
# Longitud y anchura del Sépalo, longitud y anchura del Pétalo y la variedad genética de la planta.

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# **3) ¿Qué tipo de variables son?**

# %%
tipos_de_variable = df.dtypes
print(tipos_de_variable)
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %% [markdown]
# *   **sepal_length:** Variable numérica continua (flotante) que representa la longitud del sépalo en la flor iris
# *   **sepal_width:** Variable numérica continua (flotante) que representa el ancho del sépalo en la flor iris.
# *   **petal_length:** Variable numérica continua (flotante) que representa la longitud del pétalo en la flor iris.
# *   **petal_width:** Variable numérica continua (flotante) que representa el ancho del pétalo en la flor iris.
# *   **species:** Variable categórica (cadena de texto) que representa la especie de la flor iris (setosa, versicolor o virginica).

# %% [markdown]
# **4) detectar y arreglar los valores ausentes y atípicos.**

# %%
df.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %% [markdown]
# No se detecta presencia de valores nulos

# %%
# usamos el describe para observar las estadisticas descriptivas de las variables cuantitativas
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# creamos un boxplot para ver la posible presencia de outliers
df.boxplot()
# Out:
# <Axes: >

# %%
def detect_outliers_iqr(data, column):
    q1 = data[column].quantile(0.25)
    q3 = data[column].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers

# Llamamos a la función para cada columna numérica donde desees detectar outliers
columns_to_check = ["sepal.width"]
outliers_list = []
for col in columns_to_check:
    outliers = detect_outliers_iqr(df, col)
    outliers_list.append(outliers)

# Concatenamos todos los outliers encontrados en un solo DataFrame
outliers_df = pd.concat(outliers_list)

# Eliminamos los outliers del conjunto de datos original
data_cleaned = df.drop(outliers_df.index)

# Imprimimos la cantidad de outliers detectados
print("Número de outliers detectados:", len(outliers_df))
# Out:
# Número de outliers detectados: 4

# %%
# Ahora mostramos los boxplot limpios de outliers
data_cleaned.boxplot()
data_cleaned.shape
# Out:
# (146, 5)

# %% [markdown]
# **5) Al eliminar datos, podría perder información valiosa. Sin una razón sólida para eliminar filas o columnas ni la seguridad de comprender cómo afectará mi análisis diría que no puedo eliminarlas.**

# %% [markdown]
# **6) Análisis univariados**
